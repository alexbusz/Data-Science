# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
os.chdir('downloads')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\petri\\downloads'

# %%
# Load the Excel file
excel_file = pd.ExcelFile('Country-Nutrition-Profiles-data_February_2023.xlsx')

# Get the sheet names
sheet_names = excel_file.sheet_names

# %%
# Read the data from a specific sheet
sheet_name = sheet_names[1]  # Select the second sheet, for example
df_indicator_descriptions = pd.DataFrame(excel_file.parse(sheet_name))

# Display the first few rows of the DataFrame
df_indicator_descriptions.head(20)
# Out:
#                               section name                     variable  \
# 0   The burden of malnutrition at a glance                anaemia_track
# 1   The burden of malnutrition at a glance                    lbw_track
# 2   The burden of malnutrition at a glance                    ebf_track
# 3   The burden of malnutrition at a glance       under_5_stunting_track
# 4   The burden of malnutrition at a glance        under_5_wasting_track
# 5   The burden of malnutrition at a glance     under_5_overweight_track
# 6   The burden of malnutrition at a glance      adult_fem_obesity_track
# 7   The burden of malnutrition at a glance      adult_mal_obesity_track
# 8   The burden of malnutrition at a glance     adult_fem_diabetes_track
# 9   The burden of malnutrition at a glance     adult_mal_diabetes_track
# 10  The burden of malnutrition at a glance             rbp_female_track
# 11  The burden of malnutrition at a glance               rbp_male_track
# ...

# %%
#loop through the sheets and get the data

for sheet_name in sheet_names:
  sheet_data= pd.read_excel(excel_file, sheet_name)
  print(f"Data for sheet {sheet_name}: ")
  print(sheet_data)
# Out:
# Data for sheet Cover:
#    Unnamed: 0  Unnamed: 1 Global Nutrition Report: Country Nutrition Profiles
# 0         NaN         NaN                          globalnutritionreport.org
# 1         NaN         NaN                                                NaN
# 2         NaN         NaN                                                NaN
# 3         NaN         NaN  For full details on methodology, please visit:...
# 4         NaN         NaN                                                NaN
# 5         NaN         NaN  Suggested citation: Global Nutrition Report: C...
# Data for sheet Indicator descriptions:
#                                section name  \
# 0    The burden of malnutrition at a glance
# 1    The burden of malnutrition at a glance
# 2    The burden of malnutrition at a glance
# 3    The burden of malnutrition at a glance
# 4    The burden of malnutrition at a glance
# ..                                      ...
# 130                   Environmental Impacts
# ...

# %%
sheet_data_7 = pd.read_excel('Country-Nutrition-Profiles-data_February_2023.xlsx', sheet_name=6)
print(f"Data for sheet {sheet_name}: ")
print(sheet_data)
# Out:
# Data for sheet Region environment:
#              region disaggregation                           disagg.value  \
# 0            Africa  emission_type                         Freshwater use
# 1            Africa  emission_type  Greenhouse gas emissions (life-cycle)
# 2            Africa  emission_type                               Land use
# 3            Africa  emission_type                   Nitrogen application
# 4            Africa  emission_type                 Phosphorus application
# ..              ...            ...                                    ...
# 497  Western Europe     food_group                                   oils
# 498  Western Europe     food_group                           pork_poultry
# 499  Western Europe     food_group                                  roots
# 500  Western Europe     food_group                                  sugar
# 501  Western Europe     food_group                                  total
#
# ...

# %% [markdown]
# Preparation of the Data

# %%
# Let's find out more imformation on our data

sheet_data_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5906 entries, 0 to 5905
# Columns: 324 entries, iso3 to wasting_2021
# dtypes: float64(317), object(7)
# memory usage: 14.6+ MB

# %%
sheet_data_7.shape
# Out:
# (5906, 324)

# %%
sheet_data_7.isnull()
# Out:
#        iso3  country  region  subregion  disaggregation  disagg.value  \
# 0     False    False   False      False           False         False
# 1     False    False   False      False           False         False
# 2     False    False   False      False           False         False
# 3     False    False   False      False           False         False
# 4     False    False   False      False           False         False
# ...     ...      ...     ...        ...             ...           ...
# 5901  False    False   False      False           False         False
# 5902  False    False   False      False           False         False
# 5903  False    False   False      False           False         False
# 5904  False    False   False      False           False         False
# 5905  False    False   False      False           False         False
#
#       section  adolescent_obesity_2000  adolescent_obesity_2001  \
# ...

# %%
df = sheet_data_7.dropna(axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5906 entries, 0 to 5905
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   iso3       5906 non-null   object
#  1   country    5906 non-null   object
#  2   region     5906 non-null   object
#  3   subregion  5906 non-null   object
#  4   section    5906 non-null   object
# dtypes: object(5)
# memory usage: 230.8+ KB

# %% [markdown]
# The dataset has no missing values and comprises of 14 rows and 28 columns having 24 float column data type, 3 object column data types and 1 integer column data type

# %%
# check for duplicate

df.duplicated().sum()
# Out:
# 5712

# %%
sheet_data_7
# Out:
#      iso3      country  region       subregion disaggregation    disagg.value  \
# 0     AFG  Afghanistan    Asia   Southern Asia            age     0-23 months
# 1     AFG  Afghanistan    Asia   Southern Asia            age    24-35 months
# 2     AFG  Afghanistan    Asia   Southern Asia            age    36-47 months
# 3     AFG  Afghanistan    Asia   Southern Asia            age    48-59 months
# 4     AFG  Afghanistan    Asia   Southern Asia            all       Free from
# ...   ...          ...     ...             ...            ...             ...
# 5901  ZWE     Zimbabwe  Africa  Eastern Africa         wealth         Highest
# 5902  ZWE     Zimbabwe  Africa  Eastern Africa         wealth          Lowest
# 5903  ZWE     Zimbabwe  Africa  Eastern Africa         wealth          Middle
# 5904  ZWE     Zimbabwe  Africa  Eastern Africa         wealth  Second highest
# 5905  ZWE     Zimbabwe  Africa  Eastern Africa         wealth   Second lowest
#
# ...

# %% [markdown]
# # Handling categorical values

# %%
# Check for categorical columns
for col in df.columns:
  if df[col].dtypes == 'object':
    unique_cat = len(df[col].unique())
    print("Feature '{col_name}' has {unique_cat} categories".format(col_name=col, unique_cat=unique_cat))

print()
# Out:
# Feature 'iso3' has 194 categories
# Feature 'country' has 194 categories
# Feature 'region' has 6 categories
# Feature 'subregion' has 22 categories
# Feature 'section' has 1 categories
